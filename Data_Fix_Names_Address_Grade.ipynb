# %% [markdown]
# ## Fixing Student Info

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('data/address_data.xlsx')
df.head()
# Out:
#     Unique ID     Gardian Name                      Email  \
# 0  7356714015   London Cameron          rasca@outlook.com
# 1  3233233322     Marley Allen     Marley.Allen@gmail.com
# 2  4344344433  Yair Harrington  Yair.Harrington@gmail.com
# 3  5467891234    Ashanti Huynh    Ashanti.Huynh@gmail.com
# 4  7899877799  Ashanti Sellers  Ashanti.Sellers@gmail.com
#
#                                 Address       Scholar Name Scholar Grade  \
# 0      2856 Rhonda Lane Denver CO 80207    Atticus Jackson             K
# 1  1638 E Washington St Denver CO 80219        Carlo Huang        Second
# 2   628 n Lafayette st. Denver CO 80219  Mitchell Castillo        Second
# 3       58 S 2nd street Denver CO 80219        Melina Ward        Second
# 4       58 S 2nd Street Denver CO 80219     Braden McClain        Second
#
#   Scholar 1 Enrollment Status
# 0       Application Submitted
# 1          Currently Enrolled
# 2          Currently Enrolled
# 3          Currently Enrolled
# 4          Currently Enrolled

# %% [markdown]
# ## Name Columns
#
# Change the Guardian Name and Scholar Name Columns to First and Last name columns for both Scholar and Guardian

# %%
def first_name(name):
    result = name.split()[0]
    return result
def last_name(name):
    result = name.split()[1]
    return result
#add columns and split the names
df['Guardian_First'] = df['Gardian Name'].apply(lambda x: first_name(x))
df['Guardian_last'] = df['Gardian Name'].apply(lambda x: last_name(x))
df['Scholar_First'] = df['Scholar Name'].apply(lambda x: first_name(x))
df['Scholar_Last'] = df['Scholar Name'].apply(lambda x: last_name(x))
#drop original columns
df = df.drop(['Gardian Name','Scholar Name'], axis=1)

df.head()
# Out:
#     Unique ID                      Email  \
# 0  7356714015          rasca@outlook.com
# 1  3233233322     Marley.Allen@gmail.com
# 2  4344344433  Yair.Harrington@gmail.com
# 3  5467891234    Ashanti.Huynh@gmail.com
# 4  7899877799  Ashanti.Sellers@gmail.com
#
#                                 Address Scholar Grade  \
# 0      2856 Rhonda Lane Denver CO 80207             K
# 1  1638 E Washington St Denver CO 80219        Second
# 2   628 n Lafayette st. Denver CO 80219        Second
# 3       58 S 2nd street Denver CO 80219        Second
# 4       58 S 2nd Street Denver CO 80219        Second
#
#   Scholar 1 Enrollment Status Guardian_First Guardian_last Scholar_First  \
# 0       Application Submitted         London       Cameron       Atticus
# 1          Currently Enrolled         Marley         Allen         Carlo
# 2          Currently Enrolled           Yair    Harrington      Mitchell
# 3          Currently Enrolled        Ashanti         Huynh        Melina
# 4          Currently Enrolled        Ashanti       Sellers        Braden
#
#   Scholar_Last
# 0      Jackson
# 1        Huang
# 2     Castillo
# 3         Ward
# 4      McClain

# %% [markdown]
# ## Fix the Address Column
#
# Goind to try using usaaddress and/or scourgify to create my address columns.

# %%
import usaddress

# %%
# Parse and label an address
address = "58 S 2nd Street Denver CO 80219"
parsed_address = usaddress.parse(address)

# Print the parsed address
print(parsed_address)
# Out:
# [('58', 'AddressNumber'), ('S', 'StreetNamePreDirectional'), ('2nd', 'StreetName'), ('Street', 'StreetNamePostType'), ('Denver', 'PlaceName'), ('CO', 'StateName'), ('80219', 'ZipCode')]

# %% [markdown]
# This could work but let's look at scourgify which is built on top of usaddress and will do some of lifting for us.

# %%
#scourgify https://github.com/GreenBuildingRegistry/usaddress-scourgify
from scourgify import normalize_address_record

record = normalize_address_record('58 s 2nd Street Denver CO 80219')

record
# Out:
# {'address_line_1': '58 S 2ND ST',
#  'address_line_2': None,
#  'city': 'DENVER',
#  'state': 'CO',
#  'postal_code': '80219'}

# %%
record['address_line_1']
# Out:
# '58 S 2ND ST'

# %%
print(record['address_line_2'])
# Out:
# None

# %% [markdown]
# This looks like a good starting point. We can now build a function convert the address column into it's individual parts.

# %%
## function 
def address_separator(a):
    record = normalize_address_record(a)
    #check second address line
    add2 = ""
    if record['address_line_2']:
        add2=record['address_line_2']
    #create parts of the address
    street = record['address_line_1'] + add2
    city = record['city']
    state = record['state']
    zip = record['postal_code']
    return [street, city, state, zip]

address_separator('58 s 2nd Street Denver CO 80219')
# Out:
# ['58 S 2ND ST', 'DENVER', 'CO', '80219']

# %% [markdown]
# The first step will be to temporarily create a column that has a list of the parts.

# %%
#apply this function to each row creating address part column
df['add_parts'] = df['Address'].apply(lambda row: address_separator(row))

df.head()
# Out:
#     Unique ID                      Email  \
# 0  7356714015          rasca@outlook.com
# 1  3233233322     Marley.Allen@gmail.com
# 2  4344344433  Yair.Harrington@gmail.com
# 3  5467891234    Ashanti.Huynh@gmail.com
# 4  7899877799  Ashanti.Sellers@gmail.com
#
#                                 Address Scholar Grade  \
# 0      2856 Rhonda Lane Denver CO 80207             K
# 1  1638 E Washington St Denver CO 80219        Second
# 2   628 n Lafayette st. Denver CO 80219        Second
# 3       58 S 2nd street Denver CO 80219        Second
# 4       58 S 2nd Street Denver CO 80219        Second
#
#   Scholar 1 Enrollment Status Guardian_First Guardian_last Scholar_First  \
# 0       Application Submitted         London       Cameron       Atticus
# 1          Currently Enrolled         Marley         Allen         Carlo
# 2          Currently Enrolled           Yair    Harrington      Mitchell
# 3          Currently Enrolled        Ashanti         Huynh        Melina
# 4          Currently Enrolled        Ashanti       Sellers        Braden
#
#   Scholar_Last                                  add_parts
# 0      Jackson        [2856 RHONDA LN, DENVER, CO, 80207]
# 1        Huang  [1638 E WASHINGTON ST, DENVER, CO, 80219]
# 2     Castillo    [628 N LAFAYETTE ST, DENVER, CO, 80219]
# 3         Ward           [58 S 2ND ST, DENVER, CO, 80219]
# 4      McClain           [58 S 2ND ST, DENVER, CO, 80219]

# %% [markdown]
# create columns from the add_parts

# %%
# assign values to columns
edf['street'] = df['add_parts'].apply(lambda x: x[0])
df['city'] = df['add_parts'].apply(lambda x: x[1])
df['state']= df['add_parts'].apply(lambda x: x[2])
df['zip'] = df['add_parts'].apply(lambda x: x[3])
df.head()
# Out:
#     Unique ID                      Email  \
# 0  7356714015          rasca@outlook.com
# 1  3233233322     Marley.Allen@gmail.com
# 2  4344344433  Yair.Harrington@gmail.com
# 3  5467891234    Ashanti.Huynh@gmail.com
# 4  7899877799  Ashanti.Sellers@gmail.com
#
#                                 Address Scholar Grade  \
# 0      2856 Rhonda Lane Denver CO 80207             K
# 1  1638 E Washington St Denver CO 80219        Second
# 2   628 n Lafayette st. Denver CO 80219        Second
# 3       58 S 2nd street Denver CO 80219        Second
# 4       58 S 2nd Street Denver CO 80219        Second
#
#   Scholar 1 Enrollment Status Guardian_First Guardian_last Scholar_First  \
# 0       Application Submitted         London       Cameron       Atticus
# 1          Currently Enrolled         Marley         Allen         Carlo
# 2          Currently Enrolled           Yair    Harrington      Mitchell
# 3          Currently Enrolled        Ashanti         Huynh        Melina
# 4          Currently Enrolled        Ashanti       Sellers        Braden
#
#   Scholar_Last                                  add_parts  \
# 0      Jackson        [2856 RHONDA LN, DENVER, CO, 80207]
# 1        Huang  [1638 E WASHINGTON ST, DENVER, CO, 80219]
# 2     Castillo    [628 N LAFAYETTE ST, DENVER, CO, 80219]
# 3         Ward           [58 S 2ND ST, DENVER, CO, 80219]
# 4      McClain           [58 S 2ND ST, DENVER, CO, 80219]
#
#                  street    city state    zip
# 0        2856 RHONDA LN  DENVER    CO  80207
# 1  1638 E WASHINGTON ST  DENVER    CO  80219
# 2    628 N LAFAYETTE ST  DENVER    CO  80219
# 3           58 S 2ND ST  DENVER    CO  80219
# 4           58 S 2ND ST  DENVER    CO  80219

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 189 entries, 0 to 188
# Data columns (total 14 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Unique ID                    189 non-null    object
#  1   Email                        185 non-null    object
#  2   Address                      189 non-null    object
#  3   Scholar Grade                186 non-null    object
#  4   Scholar 1 Enrollment Status  189 non-null    object
#  5   Guardian_First               189 non-null    object
#  6   Guardian_last                189 non-null    object
#  7   Scholar_First                189 non-null    object
#  8   Scholar_Last                 189 non-null    object
#  9   add_parts                    189 non-null    object
#  10  street                       189 non-null    object
#  11  city                         189 non-null    object
#  12  state                        189 non-null    object
#  13  zip                          189 non-null    object
# dtypes: object(14)
# memory usage: 20.8+ KB

# %%
df = df.drop(['Address','add_parts'],axis=1)
df.head()
# Out:
#     Unique ID                      Email Scholar Grade  \
# 0  7356714015          rasca@outlook.com             K
# 1  3233233322     Marley.Allen@gmail.com        Second
# 2  4344344433  Yair.Harrington@gmail.com        Second
# 3  5467891234    Ashanti.Huynh@gmail.com        Second
# 4  7899877799  Ashanti.Sellers@gmail.com        Second
#
#   Scholar 1 Enrollment Status Guardian_First Guardian_last Scholar_First  \
# 0       Application Submitted         London       Cameron       Atticus
# 1          Currently Enrolled         Marley         Allen         Carlo
# 2          Currently Enrolled           Yair    Harrington      Mitchell
# 3          Currently Enrolled        Ashanti         Huynh        Melina
# 4          Currently Enrolled        Ashanti       Sellers        Braden
#
#   Scholar_Last                street    city state    zip
# 0      Jackson        2856 RHONDA LN  DENVER    CO  80207
# 1        Huang  1638 E WASHINGTON ST  DENVER    CO  80219
# 2     Castillo    628 N LAFAYETTE ST  DENVER    CO  80219
# 3         Ward           58 S 2ND ST  DENVER    CO  80219
# 4      McClain           58 S 2ND ST  DENVER    CO  80219

# %% [markdown]
# ## Fix Scholar Grade
#
# The goal for this column is to get uniform grade labels.  The desired options are
# - Kindergarten
# - 1st
# - 2nd
# - PreK 3

# %%
#check the unique_values:
un_list = df['Scholar Grade'].unique().tolist()
un_list
# Out:
# ['K', 'Second', '1st', '2nd', 'Kindergarten', 'First', 'PreK 3', nan]

# %%
#create a dictionary matching each unique value to the desired string 
#these are only the ones that we need to change
grade_dict = {'K':'Kindergarten','Second':'2nd','First':'1st'}
grade_dict
# Out:
# {'K': 'Kindergarten', 'Second': '2nd', 'First': '1st'}

# %%
# creating a new column for demonstrative purposes.  
df['Scholar_Grade'] = df['Scholar Grade'].map(grade_dict).fillna(df['Scholar Grade'])
df.head()
# Out:
#     Unique ID                      Email Scholar Grade  \
# 0  7356714015          rasca@outlook.com             K
# 1  3233233322     Marley.Allen@gmail.com        Second
# 2  4344344433  Yair.Harrington@gmail.com        Second
# 3  5467891234    Ashanti.Huynh@gmail.com        Second
# 4  7899877799  Ashanti.Sellers@gmail.com        Second
#
#   Scholar 1 Enrollment Status Guardian_First Guardian_last Scholar_First  \
# 0       Application Submitted         London       Cameron       Atticus
# 1          Currently Enrolled         Marley         Allen         Carlo
# 2          Currently Enrolled           Yair    Harrington      Mitchell
# 3          Currently Enrolled        Ashanti         Huynh        Melina
# 4          Currently Enrolled        Ashanti       Sellers        Braden
#
#   Scholar_Last                street    city state    zip Scholar_Grade
# 0      Jackson        2856 RHONDA LN  DENVER    CO  80207  Kindergarten
# 1        Huang  1638 E WASHINGTON ST  DENVER    CO  80219           2nd
# 2     Castillo    628 N LAFAYETTE ST  DENVER    CO  80219           2nd
# 3         Ward           58 S 2ND ST  DENVER    CO  80219           2nd
# 4      McClain           58 S 2ND ST  DENVER    CO  80219           2nd

# %% [markdown]
# ### Drop Column for sholar grade
# We can now drop the original columns 'Scholar Grade'

# %%
df = df.drop(['Scholar Grade'],axis=1)
df.head()
# Out:
#     Unique ID                      Email Scholar 1 Enrollment Status  \
# 0  7356714015          rasca@outlook.com       Application Submitted
# 1  3233233322     Marley.Allen@gmail.com          Currently Enrolled
# 2  4344344433  Yair.Harrington@gmail.com          Currently Enrolled
# 3  5467891234    Ashanti.Huynh@gmail.com          Currently Enrolled
# 4  7899877799  Ashanti.Sellers@gmail.com          Currently Enrolled
#
#   Guardian_First Guardian_last Scholar_First Scholar_Last  \
# 0         London       Cameron       Atticus      Jackson
# 1         Marley         Allen         Carlo        Huang
# 2           Yair    Harrington      Mitchell     Castillo
# 3        Ashanti         Huynh        Melina         Ward
# 4        Ashanti       Sellers        Braden      McClain
#
#                  street    city state    zip Scholar_Grade
# 0        2856 RHONDA LN  DENVER    CO  80207  Kindergarten
# 1  1638 E WASHINGTON ST  DENVER    CO  80219           2nd
# 2    628 N LAFAYETTE ST  DENVER    CO  80219           2nd
# 3           58 S 2ND ST  DENVER    CO  80219           2nd
# 4           58 S 2ND ST  DENVER    CO  80219           2nd

# %% [markdown]
# ## Reorder Columns
# We will reorder the columns back to their original spots

# %%
cols = df.columns.tolist()
cols
# Out:
# ['Unique ID',
#  'Email',
#  'Scholar 1 Enrollment Status',
#  'Guardian_First',
#  'Guardian_last',
#  'Scholar_First',
#  'Scholar_Last',
#  'street',
#  'city',
#  'state',
#  'zip',
#  'Scholar_Grade']

# %%
#new column order
correct_order = ['Unique ID','Guardian_First','Guardian_last','Email','street','city','state','zip',
                'Scholar_First','Scholar_Last','Scholar_Grade','Scholar 1 Enrollment Status']
reordered_df = df[correct_order].copy()

# %%
#first 5 results
reordered_df.head()
# Out:
#     Unique ID Guardian_First Guardian_last                      Email  \
# 0  7356714015         London       Cameron          rasca@outlook.com
# 1  3233233322         Marley         Allen     Marley.Allen@gmail.com
# 2  4344344433           Yair    Harrington  Yair.Harrington@gmail.com
# 3  5467891234        Ashanti         Huynh    Ashanti.Huynh@gmail.com
# 4  7899877799        Ashanti       Sellers  Ashanti.Sellers@gmail.com
#
#                  street    city state    zip Scholar_First Scholar_Last  \
# 0        2856 RHONDA LN  DENVER    CO  80207       Atticus      Jackson
# 1  1638 E WASHINGTON ST  DENVER    CO  80219         Carlo        Huang
# 2    628 N LAFAYETTE ST  DENVER    CO  80219      Mitchell     Castillo
# 3           58 S 2ND ST  DENVER    CO  80219        Melina         Ward
# 4           58 S 2ND ST  DENVER    CO  80219        Braden      McClain
#
#   Scholar_Grade Scholar 1 Enrollment Status
# 0  Kindergarten       Application Submitted
# 1           2nd          Currently Enrolled
# 2           2nd          Currently Enrolled
# 3           2nd          Currently Enrolled
# 4           2nd          Currently Enrolled

# %%
reordered_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 189 entries, 0 to 188
# Data columns (total 12 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Unique ID                    189 non-null    object
#  1   Guardian_First               189 non-null    object
#  2   Guardian_last                189 non-null    object
#  3   Email                        185 non-null    object
#  4   street                       189 non-null    object
#  5   city                         189 non-null    object
#  6   state                        189 non-null    object
#  7   zip                          189 non-null    object
#  8   Scholar_First                189 non-null    object
#  9   Scholar_Last                 189 non-null    object
#  10  Scholar_Grade                186 non-null    object
#  11  Scholar 1 Enrollment Status  189 non-null    object
# dtypes: object(12)
# memory usage: 17.8+ KB

# %% [markdown]
# ## Export Files

# %%
#export to excel
reordered_df.to_excel('data/exported/cleaned_file.xlsx')
